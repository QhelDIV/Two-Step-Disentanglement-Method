# %% [markdown]
# # load sprites data

# %%
# some setup code
import torch
import torch.nn as nn
import torch.nn.functional as F 
from torch.nn import init
from torch.autograd import Variable
import torchvision
import torchvision.transforms as T
import torch.optim as optim
from torch.utils.data import DataLoader
from torch.utils.data import sampler
import torchvision.datasets as dset

import itertools

import h5py

import numpy as np

import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

import layers
import solvers

from params import *
from config import *

import utils

# %matplotlib inline
# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2
params = SPRITESParameters()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import signal
import sys
def signal_handler(signal, frame):
        print('You pressed Ctrl+C!')
        sys.exit(0)
signal.signal(signal.SIGINT, signal_handler)
print('Press Ctrl+C')
# Out:
# Press Ctrl+C

# %%
import time
from threading import Thread

def noInterrupt():
    for i in range(4):
        print(i)
        time.sleep(1)

a = Thread(target=noInterrupt)
a.start()
a.join()
print("done")
# Out:
# 0
# 1
# 2
# 3
# done

# %%
import signal
import sys
def signal_handler(signal, frame):
        print('You pressed Ctrl+C!')
        sys.exit(0)
signal.signal(signal.SIGINT, signal_handler)
print('Press Ctrl+C')
signal.pause()
# Out:
# Press Ctrl+C
# You pressed Ctrl+C!
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# /home/qheldiv/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2918: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
for sprite_index in range(20):
    testfile = 'datasets/sprites/sprites_%d.mat'%(sprite_index)
    f = h5py.File(testfile)
    sprites = list(f.values())[3]

    img_list = []
    for ch in range(20):
        h5ref = np.array(sprites)[ch][0]
        imgs = np.array(f[h5ref])
        frames = imgs.size // 3//60//60
        imgs = imgs.reshape(frames,3,60,60).transpose(0,1,3,2)
        for i in range(frames):
            img_list.append(imgs[i])
    utils.show_images(np.stack(img_list),params)
    plt.show()

# %%
total_label = 672

# %%
img_list = []
for sprite_index in range(total_label):
    testfile = 'datasets/sprites/sprites_%d.mat'%(sprite_index)
    f = h5py.File(testfile)
    sprites = list(f.values())[3]

    for ch in range(20):
        h5ref = np.array(sprites)[ch][0]
        imgs = np.array(f[h5ref])
        frames = imgs.size // 3//60//60
        imgs = imgs.reshape(frames,3,60,60).transpose(0,1,3,2)
        img_list.append( torch.tensor(imgs))
img_dataset = torch.cat(img_list)

# %%
torch.save(img_dataset,'sprites_data.pt')

# %%
img_dataset.shape
# Out:
# torch.Size([115584, 3, 60, 60])

# %%
sprites_loaded = torch.load('sprites_data.pt')

# %%
sprites_loaded.shape
# Out:
# torch.Size([115584, 3, 60, 60])
